# %%
## Import the essential library

import os
import requests
import pandas as pd
import numpy as np
from dotenv import load_dotenv
from pathlib import Path
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from datetime import datetime, timedelta

# %%
# Load the enviornment
load_dotenv()
# Out:
# True

# %%
#Get the Twitter bearer token from the .env file

twitter_bearer_token = os.getenv("TWITTER_BEARER_TOKEN")

#Check if retrieved
type(twitter_bearer_token)
# Out:
# str

# %%
## Read the ticker symbols from CSV and put it in the dataframe
csvpath = Path("Data/StockPriceData.csv")
df_stock_price_data = pd.read_csv(csvpath, infer_datetime_format=True, parse_dates=True)

#Delete the unnecessary index column from CSV
df_stock_price_data = df_stock_price_data.drop(columns=df_stock_price_data.columns[0])
df_stock_price_data.dtypes
# Out:
# Date       object
# Close     float64
# Ticker     object
# dtype: object

# %%
#List of unique tickers
tickers_list = list(set(df_stock_price_data['Ticker']))
tickers_list
# Out:
# ['SHCRW',
#  'OEPWU',
#  'CREC',
#  'KWR',
#  'HORI',
#  'ACLX',
#  'IMH',
#  'WNC',
#  'TRIP',
#  'GBX',
#  'AACI',
#  'COSM',
#  'SQ',
#  'DOCU',
#  'GRC',
#  'FCT',
#  'WEX',
#  'DRQ',
#  'MAR',
#  'PWR',
#  'MPRAU',
#  'POAI',
#  'HGEN',
#  'SBNY',
#  'BKCC',
#  'IVCB',
#  'INSW',
#  'SBTX',
#  'CGABL',
#  'CBRGW',
#  'BSM']

# %%
# Set the Bearer Token for Authorisation for Twitter API call.
auth_token = "Bearer " + twitter_bearer_token
headers = {"Authorization": auth_token}

## Function to read 100 recent tweets related to ticker and from the date time specified.
def read_100_Tweets(ticker, tweet_date_time):
    ## Function to read 100 recent tweets from the specific dates
    ##  Input : ticker - Stock Ticker
    ##          tweet_date_time - UTC Date/Time Format YYYY-MM-DDTHH:mm:ssZ (ISO 8601/RFC 3339)
    ## 
    ##  Output: List of 100 tweets
    twitter_api_url  = f"https://api.twitter.com/2/tweets/search/recent?max_results=100&query={ticker}&end_time={tweet_date_time}"
    response = requests.get(twitter_api_url, headers=headers)
    ## Check for 200 status code which means it was successful
    tweets_list = [];
    if(response.status_code == 200):
        json_response = response.json()
        #Check if there are any tweets at all
        if('data' in json_response.keys()): 
            all_tweets = response.json()["data"]
            for tweet in all_tweets:
                tweets_list.append(tweet["text"])
            
    else:
        print(f"Response code: {response.status_code}.  Error in getting the tweet");
    return tweets_list

# %%
## Perform Vader Sentiment Analysis

## Define Sentiment Object for Sentiment Analysis

sentiment_obj = SentimentIntensityAnalyzer()
def perform_sentiment_analysis(tweets_list):
    ## Function to read 100 recent tweets from the specific dates
    ##  Input : tweets_list - List of 100 tweets
    ##          
    ## 
    ##  Output: sentiment score average
    
    ##Check if there are tweets to analyse
    if (len(tweets_list) > 0):
        sentiment_scores_all = []
        for tweet in tweets_list:
            sentiment_dict = sentiment_obj.polarity_scores(tweet)
            sentiment_scores_all.append(sentiment_dict["compound"])

        #Average the sentiment of all tweets    
        average_sentiment = np.average(sentiment_scores_all)
        return average_sentiment
    else:
        return 0;

# %%
#perform_sentiment_analysis(tweets_list)

# %%
def execute_tweet_sentiment_analysis(start_date, end_date):
    
    tweet_sentiments = []

    while start_date <= end_date:
        delta = timedelta(hours=4)
        for ticker in tickers_list:
            if(start_date.hour == 0 or start_date.hour == 4 ):
                continue
            print(f"Executing Tweet Analysis for {ticker} on {start_date.isoformat()}")
            tweets_list = []
            tweets_list = read_100_Tweets(ticker, start_date.isoformat() + "Z")
            sentiment_score = perform_sentiment_analysis(tweets_list)
            tweet_sentiment = {}
            tweet_sentiment["Ticker"] = ticker
            tweet_sentiment["Date"] = start_date
            tweet_sentiment["Sentiment_Score"] = sentiment_score
            tweet_sentiments.append(tweet_sentiment)
            #print("Ticker: " + tweet_sentiment["ticker"] + ", Date : " + str(tweet_sentiment["date"]) + ", Sentiment Score: " + str(tweet_sentiment["sentiment_score"]))
        start_date += delta
    return tweet_sentiments

# %%
start_date = datetime(2022,5,10, 12,0,0)
end_date = datetime(2022,5,12, 0,0,0)
tweet_sentiments = []
tweet_sentiments = execute_tweet_sentiment_analysis(start_date, end_date)
# Out:
# Executing Tweet Analysis for SHCRW on 2022-05-10T12:00:00
# Executing Tweet Analysis for OEPWU on 2022-05-10T12:00:00
# Executing Tweet Analysis for CREC on 2022-05-10T12:00:00
# Executing Tweet Analysis for KWR on 2022-05-10T12:00:00
# Executing Tweet Analysis for HORI on 2022-05-10T12:00:00
# Executing Tweet Analysis for ACLX on 2022-05-10T12:00:00
# Executing Tweet Analysis for IMH on 2022-05-10T12:00:00
# Executing Tweet Analysis for WNC on 2022-05-10T12:00:00
# Executing Tweet Analysis for TRIP on 2022-05-10T12:00:00
# Executing Tweet Analysis for GBX on 2022-05-10T12:00:00
# Executing Tweet Analysis for AACI on 2022-05-10T12:00:00
# Executing Tweet Analysis for COSM on 2022-05-10T12:00:00
# Executing Tweet Analysis for SQ on 2022-05-10T12:00:00
# Executing Tweet Analysis for DOCU on 2022-05-10T12:00:00
# Executing Tweet Analysis for GRC on 2022-05-10T12:00:00
# Executing Tweet Analysis for FCT on 2022-05-10T12:00:00
# Executing Tweet Analysis for WEX on 2022-05-10T12:00:00
# Executing Tweet Analysis for DRQ on 2022-05-10T12:00:00
# Executing Tweet Analysis for MAR on 2022-05-10T12:00:00
# Executing Tweet Analysis for PWR on 2022-05-10T12:00:00
# Executing Tweet Analysis for MPRAU on 2022-05-10T12:00:00
# Executing Tweet Analysis for POAI on 2022-05-10T12:00:00
# Executing Tweet Analysis for HGEN on 2022-05-10T12:00:00
# Executing Tweet Analysis for SBNY on 2022-05-10T12:00:00
# Executing Tweet Analysis for BKCC on 2022-05-10T12:00:00
# Executing Tweet Analysis for IVCB on 2022-05-10T12:00:00
# Executing Tweet Analysis for INSW on 2022-05-10T12:00:00
# Executing Tweet Analysis for SBTX on 2022-05-10T12:00:00
# Executing Tweet Analysis for CGABL on 2022-05-10T12:00:00
# Executing Tweet Analysis for CBRGW on 2022-05-10T12:00:00
# Executing Tweet Analysis for BSM on 2022-05-10T12:00:00
# Executing Tweet Analysis for SHCRW on 2022-05-10T16:00:00
# Executing Tweet Analysis for OEPWU on 2022-05-10T16:00:00
# Executing Tweet Analysis for CREC on 2022-05-10T16:00:00
# Executing Tweet Analysis for KWR on 2022-05-10T16:00:00
# Executing Tweet Analysis for HORI on 2022-05-10T16:00:00
# Executing Tweet Analysis for ACLX on 2022-05-10T16:00:00
# Executing Tweet Analysis for IMH on 2022-05-10T16:00:00
# Executing Tweet Analysis for WNC on 2022-05-10T16:00:00
# Executing Tweet Analysis for TRIP on 2022-05-10T16:00:00
# Executing Tweet Analysis for GBX on 2022-05-10T16:00:00
# Executing Tweet Analysis for AACI on 2022-05-10T16:00:00
# Executing Tweet Analysis for COSM on 2022-05-10T16:00:00
# Executing Tweet Analysis for SQ on 2022-05-10T16:00:00
# Executing Tweet Analysis for DOCU on 2022-05-10T16:00:00
# Executing Tweet Analysis for GRC on 2022-05-10T16:00:00
# Executing Tweet Analysis for FCT on 2022-05-10T16:00:00
# Executing Tweet Analysis for WEX on 2022-05-10T16:00:00
# Executing Tweet Analysis for DRQ on 2022-05-10T16:00:00
# Executing Tweet Analysis for MAR on 2022-05-10T16:00:00
# Executing Tweet Analysis for PWR on 2022-05-10T16:00:00
# Executing Tweet Analysis for MPRAU on 2022-05-10T16:00:00
# Executing Tweet Analysis for POAI on 2022-05-10T16:00:00
# Executing Tweet Analysis for HGEN on 2022-05-10T16:00:00
# Executing Tweet Analysis for SBNY on 2022-05-10T16:00:00
# Executing Tweet Analysis for BKCC on 2022-05-10T16:00:00
# Executing Tweet Analysis for IVCB on 2022-05-10T16:00:00
# Executing Tweet Analysis for INSW on 2022-05-10T16:00:00
# Executing Tweet Analysis for SBTX on 2022-05-10T16:00:00
# Executing Tweet Analysis for CGABL on 2022-05-10T16:00:00
# Executing Tweet Analysis for CBRGW on 2022-05-10T16:00:00
# Executing Tweet Analysis for BSM on 2022-05-10T16:00:00
# Executing Tweet Analysis for SHCRW on 2022-05-10T20:00:00
# Executing Tweet Analysis for OEPWU on 2022-05-10T20:00:00
# Executing Tweet Analysis for CREC on 2022-05-10T20:00:00
# Executing Tweet Analysis for KWR on 2022-05-10T20:00:00
# Executing Tweet Analysis for HORI on 2022-05-10T20:00:00
# Executing Tweet Analysis for ACLX on 2022-05-10T20:00:00
# Executing Tweet Analysis for IMH on 2022-05-10T20:00:00
# Executing Tweet Analysis for WNC on 2022-05-10T20:00:00
# Executing Tweet Analysis for TRIP on 2022-05-10T20:00:00
# Executing Tweet Analysis for GBX on 2022-05-10T20:00:00
# Executing Tweet Analysis for AACI on 2022-05-10T20:00:00
# Executing Tweet Analysis for COSM on 2022-05-10T20:00:00
# Executing Tweet Analysis for SQ on 2022-05-10T20:00:00
# Executing Tweet Analysis for DOCU on 2022-05-10T20:00:00
# Executing Tweet Analysis for GRC on 2022-05-10T20:00:00
# Executing Tweet Analysis for FCT on 2022-05-10T20:00:00
# Executing Tweet Analysis for WEX on 2022-05-10T20:00:00
# Executing Tweet Analysis for DRQ on 2022-05-10T20:00:00
# Executing Tweet Analysis for MAR on 2022-05-10T20:00:00
# Executing Tweet Analysis for PWR on 2022-05-10T20:00:00
# Executing Tweet Analysis for MPRAU on 2022-05-10T20:00:00
# Executing Tweet Analysis for POAI on 2022-05-10T20:00:00
# Executing Tweet Analysis for HGEN on 2022-05-10T20:00:00
# Executing Tweet Analysis for SBNY on 2022-05-10T20:00:00
# Executing Tweet Analysis for BKCC on 2022-05-10T20:00:00
# Executing Tweet Analysis for IVCB on 2022-05-10T20:00:00
# Executing Tweet Analysis for INSW on 2022-05-10T20:00:00
# Executing Tweet Analysis for SBTX on 2022-05-10T20:00:00
# Executing Tweet Analysis for CGABL on 2022-05-10T20:00:00
# Executing Tweet Analysis for CBRGW on 2022-05-10T20:00:00
# Executing Tweet Analysis for BSM on 2022-05-10T20:00:00
# Executing Tweet Analysis for SHCRW on 2022-05-11T08:00:00
# Executing Tweet Analysis for OEPWU on 2022-05-11T08:00:00
# Executing Tweet Analysis for CREC on 2022-05-11T08:00:00
# Executing Tweet Analysis for KWR on 2022-05-11T08:00:00
# Executing Tweet Analysis for HORI on 2022-05-11T08:00:00
# Executing Tweet Analysis for ACLX on 2022-05-11T08:00:00
# Executing Tweet Analysis for IMH on 2022-05-11T08:00:00
# Executing Tweet Analysis for WNC on 2022-05-11T08:00:00
# Executing Tweet Analysis for TRIP on 2022-05-11T08:00:00
# Executing Tweet Analysis for GBX on 2022-05-11T08:00:00
# Executing Tweet Analysis for AACI on 2022-05-11T08:00:00
# Executing Tweet Analysis for COSM on 2022-05-11T08:00:00
# Executing Tweet Analysis for SQ on 2022-05-11T08:00:00
# Executing Tweet Analysis for DOCU on 2022-05-11T08:00:00
# Executing Tweet Analysis for GRC on 2022-05-11T08:00:00
# Executing Tweet Analysis for FCT on 2022-05-11T08:00:00
# Executing Tweet Analysis for WEX on 2022-05-11T08:00:00
# Executing Tweet Analysis for DRQ on 2022-05-11T08:00:00
# Executing Tweet Analysis for MAR on 2022-05-11T08:00:00
# Executing Tweet Analysis for PWR on 2022-05-11T08:00:00
# Executing Tweet Analysis for MPRAU on 2022-05-11T08:00:00
# Executing Tweet Analysis for POAI on 2022-05-11T08:00:00
# Executing Tweet Analysis for HGEN on 2022-05-11T08:00:00
# Executing Tweet Analysis for SBNY on 2022-05-11T08:00:00
# Executing Tweet Analysis for BKCC on 2022-05-11T08:00:00
# Executing Tweet Analysis for IVCB on 2022-05-11T08:00:00
# Executing Tweet Analysis for INSW on 2022-05-11T08:00:00
# Executing Tweet Analysis for SBTX on 2022-05-11T08:00:00
# Executing Tweet Analysis for CGABL on 2022-05-11T08:00:00
# Executing Tweet Analysis for CBRGW on 2022-05-11T08:00:00
# Executing Tweet Analysis for BSM on 2022-05-11T08:00:00
# Executing Tweet Analysis for SHCRW on 2022-05-11T12:00:00
# Executing Tweet Analysis for OEPWU on 2022-05-11T12:00:00
# Executing Tweet Analysis for CREC on 2022-05-11T12:00:00
# Executing Tweet Analysis for KWR on 2022-05-11T12:00:00
# Executing Tweet Analysis for HORI on 2022-05-11T12:00:00
# Executing Tweet Analysis for ACLX on 2022-05-11T12:00:00
# Executing Tweet Analysis for IMH on 2022-05-11T12:00:00
# Executing Tweet Analysis for WNC on 2022-05-11T12:00:00
# Executing Tweet Analysis for TRIP on 2022-05-11T12:00:00
# Executing Tweet Analysis for GBX on 2022-05-11T12:00:00
# Executing Tweet Analysis for AACI on 2022-05-11T12:00:00
# Executing Tweet Analysis for COSM on 2022-05-11T12:00:00
# Executing Tweet Analysis for SQ on 2022-05-11T12:00:00
# Executing Tweet Analysis for DOCU on 2022-05-11T12:00:00
# Executing Tweet Analysis for GRC on 2022-05-11T12:00:00
# Executing Tweet Analysis for FCT on 2022-05-11T12:00:00
# Executing Tweet Analysis for WEX on 2022-05-11T12:00:00
# Executing Tweet Analysis for DRQ on 2022-05-11T12:00:00
# Executing Tweet Analysis for MAR on 2022-05-11T12:00:00
# Executing Tweet Analysis for PWR on 2022-05-11T12:00:00
# Executing Tweet Analysis for MPRAU on 2022-05-11T12:00:00
# Executing Tweet Analysis for POAI on 2022-05-11T12:00:00
# Executing Tweet Analysis for HGEN on 2022-05-11T12:00:00
# Executing Tweet Analysis for SBNY on 2022-05-11T12:00:00
# Executing Tweet Analysis for BKCC on 2022-05-11T12:00:00
# Executing Tweet Analysis for IVCB on 2022-05-11T12:00:00
# Executing Tweet Analysis for INSW on 2022-05-11T12:00:00
# Executing Tweet Analysis for SBTX on 2022-05-11T12:00:00
# Executing Tweet Analysis for CGABL on 2022-05-11T12:00:00
# Executing Tweet Analysis for CBRGW on 2022-05-11T12:00:00
# Executing Tweet Analysis for BSM on 2022-05-11T12:00:00
# Executing Tweet Analysis for SHCRW on 2022-05-11T16:00:00
# Executing Tweet Analysis for OEPWU on 2022-05-11T16:00:00
# Executing Tweet Analysis for CREC on 2022-05-11T16:00:00
# Executing Tweet Analysis for KWR on 2022-05-11T16:00:00
# Executing Tweet Analysis for HORI on 2022-05-11T16:00:00
# Executing Tweet Analysis for ACLX on 2022-05-11T16:00:00
# Executing Tweet Analysis for IMH on 2022-05-11T16:00:00
# Executing Tweet Analysis for WNC on 2022-05-11T16:00:00
# Executing Tweet Analysis for TRIP on 2022-05-11T16:00:00
# Executing Tweet Analysis for GBX on 2022-05-11T16:00:00
# Executing Tweet Analysis for AACI on 2022-05-11T16:00:00
# Executing Tweet Analysis for COSM on 2022-05-11T16:00:00
# Executing Tweet Analysis for SQ on 2022-05-11T16:00:00
# Executing Tweet Analysis for DOCU on 2022-05-11T16:00:00
# Executing Tweet Analysis for GRC on 2022-05-11T16:00:00
# Executing Tweet Analysis for FCT on 2022-05-11T16:00:00
# Executing Tweet Analysis for WEX on 2022-05-11T16:00:00
# Executing Tweet Analysis for DRQ on 2022-05-11T16:00:00
# Executing Tweet Analysis for MAR on 2022-05-11T16:00:00
# Executing Tweet Analysis for PWR on 2022-05-11T16:00:00
# Executing Tweet Analysis for MPRAU on 2022-05-11T16:00:00
# Executing Tweet Analysis for POAI on 2022-05-11T16:00:00
# Executing Tweet Analysis for HGEN on 2022-05-11T16:00:00
# Executing Tweet Analysis for SBNY on 2022-05-11T16:00:00
# Executing Tweet Analysis for BKCC on 2022-05-11T16:00:00
# Executing Tweet Analysis for IVCB on 2022-05-11T16:00:00
# Executing Tweet Analysis for INSW on 2022-05-11T16:00:00
# Executing Tweet Analysis for SBTX on 2022-05-11T16:00:00
# Executing Tweet Analysis for CGABL on 2022-05-11T16:00:00
# Executing Tweet Analysis for CBRGW on 2022-05-11T16:00:00
# Executing Tweet Analysis for BSM on 2022-05-11T16:00:00
# Executing Tweet Analysis for SHCRW on 2022-05-11T20:00:00
# Executing Tweet Analysis for OEPWU on 2022-05-11T20:00:00
# Executing Tweet Analysis for CREC on 2022-05-11T20:00:00
# Executing Tweet Analysis for KWR on 2022-05-11T20:00:00
# Executing Tweet Analysis for HORI on 2022-05-11T20:00:00
# Executing Tweet Analysis for ACLX on 2022-05-11T20:00:00
# Executing Tweet Analysis for IMH on 2022-05-11T20:00:00
# Executing Tweet Analysis for WNC on 2022-05-11T20:00:00
# Executing Tweet Analysis for TRIP on 2022-05-11T20:00:00
# Executing Tweet Analysis for GBX on 2022-05-11T20:00:00
# Executing Tweet Analysis for AACI on 2022-05-11T20:00:00
# Executing Tweet Analysis for COSM on 2022-05-11T20:00:00
# Executing Tweet Analysis for SQ on 2022-05-11T20:00:00
# Executing Tweet Analysis for DOCU on 2022-05-11T20:00:00
# Executing Tweet Analysis for GRC on 2022-05-11T20:00:00
# Executing Tweet Analysis for FCT on 2022-05-11T20:00:00
# Executing Tweet Analysis for WEX on 2022-05-11T20:00:00
# Executing Tweet Analysis for DRQ on 2022-05-11T20:00:00
# Executing Tweet Analysis for MAR on 2022-05-11T20:00:00
# Executing Tweet Analysis for PWR on 2022-05-11T20:00:00
# Executing Tweet Analysis for MPRAU on 2022-05-11T20:00:00
# Executing Tweet Analysis for POAI on 2022-05-11T20:00:00
# Executing Tweet Analysis for HGEN on 2022-05-11T20:00:00
# Executing Tweet Analysis for SBNY on 2022-05-11T20:00:00
# Executing Tweet Analysis for BKCC on 2022-05-11T20:00:00
# Executing Tweet Analysis for IVCB on 2022-05-11T20:00:00
# Executing Tweet Analysis for INSW on 2022-05-11T20:00:00
# Executing Tweet Analysis for SBTX on 2022-05-11T20:00:00
# Executing Tweet Analysis for CGABL on 2022-05-11T20:00:00
# Executing Tweet Analysis for CBRGW on 2022-05-11T20:00:00
# Executing Tweet Analysis for BSM on 2022-05-11T20:00:00
# [{'Ticker': 'SHCRW',
#   'Date': datetime.datetime(2022, 5, 10, 12, 0),
#   'Sentiment_Score': 0},
#  {'Ticker': 'OEPWU',
#   'Date': datetime.datetime(2022, 5, 10, 12, 0),
#   'Sentiment_Score': 0},
#  {'Ticker': 'CREC',
#   'Date': datetime.datetime(2022, 5, 10, 12, 0),
#   'Sentiment_Score': -0.06088585858585858},
#  {'Ticker': 'KWR',
#   'Date': datetime.datetime(2022, 5, 10, 12, 0),
#   'Sentiment_Score': -0.233375},
#  {'Ticker': 'HORI',
#   'Date': datetime.datetime(2022, 5, 10, 12, 0),
#   'Sentiment_Score': 0.100716},
#  {'Ticker': 'ACLX',
#   'Date': datetime.datetime(2022, 5, 10, 12, 0),
#   'Sentiment_Score': 0},
#  {'Ticker': 'IMH',
#   'Date': datetime.datetime(2022, 5, 10, 12, 0),
#   'Sentiment_Score': 0.11356250000000002},
#  {'Ticker': 'WNC',
#   'Date': datetime.datetime(2022, 5, 10, 12, 0),
#   'Sentiment_Score': 0.11606315789473684},
#  {'Ticker': 'TRIP',
#   'Date': datetime.datetime(2022, 5, 10, 12, 0),
#   'Sentiment_Score': 0.23439899999999997},
#  {'Ticker': 'GBX',
#   'Date': datetime.datetime(2022, 5, 10, 12, 0),
#   'Sentiment_Score': 0.6705},
#  {'Ticker': 'AACI',
#   'Date': datetime.datetime(2022, 5, 10, 12, 0),
#   'Sentiment_Score': 0},
#  {'Ticker': 'COSM',
#   'Date': datetime.datetime(2022, 5, 10, 12, 0),
#   'Sentiment_Score': 0.026325000000000005},
#  {'Ticker': 'SQ',
#   'Date': datetime.datetime(2022, 5, 10, 12, 0),
#   'Sentiment_Score': 0.196338},
#  {'Ticker': 'DOCU',
#   'Date': datetime.datetime(2022, 5, 10, 12, 0),
#   'Sentiment_Score': -0.008534343434343429},
#  {'Ticker': 'GRC',
#   'Date': datetime.datetime(2022, 5, 10, 12, 0),
#   'Sentiment_Score': 0.10286923076923077},
#  {'Ticker': 'FCT',
#   'Date': datetime.datetime(2022, 5, 10, 12, 0),
#   'Sentiment_Score': 0.091810101010101},
#  {'Ticker': 'WEX',
#   'Date': datetime.datetime(2022, 5, 10, 12, 0),
#   'Sentiment_Score': 0.41427500000000006},
#  {'Ticker': 'DRQ',
#   'Date': datetime.datetime(2022, 5, 10, 12, 0),
#   'Sentiment_Score': 0.427775},
#  {'Ticker': 'MAR',
#   'Date': datetime.datetime(2022, 5, 10, 12, 0),
#   'Sentiment_Score': 0.09760303030303032},
#  {'Ticker': 'PWR',
#   'Date': datetime.datetime(2022, 5, 10, 12, 0),
#   'Sentiment_Score': 0.17913125000000002},
#  {'Ticker': 'MPRAU',
#   'Date': datetime.datetime(2022, 5, 10, 12, 0),
#   'Sentiment_Score': 0},
#  {'Ticker': 'POAI',
#   'Date': datetime.datetime(2022, 5, 10, 12, 0),
#   'Sentiment_Score': 0.0},
#  {'Ticker': 'HGEN',
#   'Date': datetime.datetime(2022, 5, 10, 12, 0),
#   'Sentiment_Score': 0.0},
#  {'Ticker': 'SBNY',
#   'Date': datetime.datetime(2022, 5, 10, 12, 0),
#   'Sentiment_Score': 0.6597},
#  {'Ticker': 'BKCC',
#   'Date': datetime.datetime(2022, 5, 10, 12, 0),
#   'Sentiment_Score': 0.0},
#  {'Ticker': 'IVCB',
#   'Date': datetime.datetime(2022, 5, 10, 12, 0),
#   'Sentiment_Score': 0},
#  {'Ticker': 'INSW',
#   'Date': datetime.datetime(2022, 5, 10, 12, 0),
#   'Sentiment_Score': 0},
#  {'Ticker': 'SBTX',
#   'Date': datetime.datetime(2022, 5, 10, 12, 0),
#   'Sentiment_Score': 0},
#  {'Ticker': 'CGABL',
#   'Date': datetime.datetime(2022, 5, 10, 12, 0),
#   'Sentiment_Score': 0},
#  {'Ticker': 'CBRGW',
#   'Date': datetime.datetime(2022, 5, 10, 12, 0),
#   'Sentiment_Score': 0},
#  {'Ticker': 'BSM',
#   'Date': datetime.datetime(2022, 5, 10, 12, 0),
#   'Sentiment_Score': -0.02788},
#  {'Ticker': 'SHCRW',
#   'Date': datetime.datetime(2022, 5, 10, 16, 0),
#   'Sentiment_Score': 0},
#  {'Ticker': 'OEPWU',
#   'Date': datetime.datetime(2022, 5, 10, 16, 0),
#   'Sentiment_Score': 0},
#  {'Ticker': 'CREC',
#   'Date': datetime.datetime(2022, 5, 10, 16, 0),
#   'Sentiment_Score': -0.024868999999999995},
#  {'Ticker': 'KWR',
#   'Date': datetime.datetime(2022, 5, 10, 16, 0),
#   'Sentiment_Score': 0.035705050505050503},
#  {'Ticker': 'HORI',
#   'Date': datetime.datetime(2022, 5, 10, 16, 0),
#   'Sentiment_Score': 0.06123814432989692},
#  {'Ticker': 'ACLX',
#   'Date': datetime.datetime(2022, 5, 10, 16, 0),
#   'Sentiment_Score': 0.032888888888888884},
#  {'Ticker': 'IMH',
#   'Date': datetime.datetime(2022, 5, 10, 16, 0),
#   'Sentiment_Score': 0.3746616161616162},
#  {'Ticker': 'WNC',
#   'Date': datetime.datetime(2022, 5, 10, 16, 0),
#   'Sentiment_Score': 0.15066000000000002},
#  {'Ticker': 'TRIP',
#   'Date': datetime.datetime(2022, 5, 10, 16, 0),
#   'Sentiment_Score': 0.147099},
#  {'Ticker': 'GBX',
#   'Date': datetime.datetime(2022, 5, 10, 16, 0),
#   'Sentiment_Score': 0.21247857142857143},
#  {'Ticker': 'AACI',
#   'Date': datetime.datetime(2022, 5, 10, 16, 0),
#   'Sentiment_Score': -0.10115},
#  {'Ticker': 'COSM',
#   'Date': datetime.datetime(2022, 5, 10, 16, 0),
#   'Sentiment_Score': 0.029239},
#  {'Ticker': 'SQ',
#   'Date': datetime.datetime(2022, 5, 10, 16, 0),
#   'Sentiment_Score': 0.13117755102040815},
#  {'Ticker': 'DOCU',
#   'Date': datetime.datetime(2022, 5, 10, 16, 0),
#   'Sentiment_Score': 0.058953000000000005},
#  {'Ticker': 'GRC',
#   'Date': datetime.datetime(2022, 5, 10, 16, 0),
#   'Sentiment_Score': 0.12718700000000002},
#  {'Ticker': 'FCT',
#   'Date': datetime.datetime(2022, 5, 10, 16, 0),
#   'Sentiment_Score': 0.22311599999999998},
#  {'Ticker': 'WEX',
#   'Date': datetime.datetime(2022, 5, 10, 16, 0),
#   'Sentiment_Score': 0.15793333333333337},
#  {'Ticker': 'DRQ',
#   'Date': datetime.datetime(2022, 5, 10, 16, 0),
#   'Sentiment_Score': 0.17283333333333334},
#  {'Ticker': 'MAR',
#   'Date': datetime.datetime(2022, 5, 10, 16, 0),
#   'Sentiment_Score': 0.051338775510204084},
#  {'Ticker': 'PWR',
#   'Date': datetime.datetime(2022, 5, 10, 16, 0),
#   'Sentiment_Score': 0.131534375},
#  {'Ticker': 'MPRAU',
#   'Date': datetime.datetime(2022, 5, 10, 16, 0),
#   'Sentiment_Score': 0},
#  {'Ticker': 'POAI',
#   'Date': datetime.datetime(2022, 5, 10, 16, 0),
#   'Sentiment_Score': 0.08901428571428571},
#  {'Ticker': 'HGEN',
#   'Date': datetime.datetime(2022, 5, 10, 16, 0),
#   'Sentiment_Score': 0.055367999999999994},
#  {'Ticker': 'SBNY',
#   'Date': datetime.datetime(2022, 5, 10, 16, 0),
#   'Sentiment_Score': 0.23206923076923078},
#  {'Ticker': 'BKCC',
#   'Date': datetime.datetime(2022, 5, 10, 16, 0),
#   'Sentiment_Score': -0.074},
#  {'Ticker': 'IVCB',
#   'Date': datetime.datetime(2022, 5, 10, 16, 0),
#   'Sentiment_Score': 0.2294},
#  {'Ticker': 'INSW',
#   'Date': datetime.datetime(2022, 5, 10, 16, 0),
#   'Sentiment_Score': -0.0325},
#  {'Ticker': 'SBTX',
#   'Date': datetime.datetime(2022, 5, 10, 16, 0),
#   'Sentiment_Score': 0.3182},
#  {'Ticker': 'CGABL',
#   'Date': datetime.datetime(2022, 5, 10, 16, 0),
#   'Sentiment_Score': 0},
#  {'Ticker': 'CBRGW',
#   'Date': datetime.datetime(2022, 5, 10, 16, 0),
#   'Sentiment_Score': 0},
#  {'Ticker': 'BSM',
#   'Date': datetime.datetime(2022, 5, 10, 16, 0),
#   'Sentiment_Score': 0.036004999999999995},
#  {'Ticker': 'SHCRW',
#   'Date': datetime.datetime(2022, 5, 10, 20, 0),
#   'Sentiment_Score': 0},
#  {'Ticker': 'OEPWU',
#   'Date': datetime.datetime(2022, 5, 10, 20, 0),
#   'Sentiment_Score': 0},
#  {'Ticker': 'CREC',
#   'Date': datetime.datetime(2022, 5, 10, 20, 0),
#   'Sentiment_Score': -0.06770199999999998},
#  {'Ticker': 'KWR',
#   'Date': datetime.datetime(2022, 5, 10, 20, 0),
#   'Sentiment_Score': 0.049579000000000005},
#  {'Ticker': 'HORI',
#   'Date': datetime.datetime(2022, 5, 10, 20, 0),
#   'Sentiment_Score': 0.13173092783505153},
#  {'Ticker': 'ACLX',
#   'Date': datetime.datetime(2022, 5, 10, 20, 0),
#   'Sentiment_Score': 0.005808333333333332},
#  {'Ticker': 'IMH',
#   'Date': datetime.datetime(2022, 5, 10, 20, 0),
#   'Sentiment_Score': 0.48110404040404026},
#  {'Ticker': 'WNC',
#   'Date': datetime.datetime(2022, 5, 10, 20, 0),
#   'Sentiment_Score': 0.11955099999999998},
#  {'Ticker': 'TRIP',
#   'Date': datetime.datetime(2022, 5, 10, 20, 0),
#   'Sentiment_Score': 0.09565050505050504},
#  {'Ticker': 'GBX',
#   'Date': datetime.datetime(2022, 5, 10, 20, 0),
#   'Sentiment_Score': 0.17965599999999998},
#  {'Ticker': 'AACI',
#   'Date': datetime.datetime(2022, 5, 10, 20, 0),
#   'Sentiment_Score': -0.06743333333333333},
#  {'Ticker': 'COSM',
#   'Date': datetime.datetime(2022, 5, 10, 20, 0),
#   'Sentiment_Score': 0.053613},
#  {'Ticker': 'SQ',
#   'Date': datetime.datetime(2022, 5, 10, 20, 0),
#   'Sentiment_Score': 0.0968868686868687},
#  {'Ticker': 'DOCU',
#   'Date': datetime.datetime(2022, 5, 10, 20, 0),
#   'Sentiment_Score': 0.121861},
#  {'Ticker': 'GRC',
#   'Date': datetime.datetime(2022, 5, 10, 20, 0),
#   'Sentiment_Score': -0.023296938775510204},
#  {'Ticker': 'FCT',
#   'Date': datetime.datetime(2022, 5, 10, 20, 0),
#   'Sentiment_Score': -0.04474949494949495},
#  {'Ticker': 'WEX',
#   'Date': datetime.datetime(2022, 5, 10, 20, 0),
#   'Sentiment_Score': 0.14617},
#  {'Ticker': 'DRQ',
#   'Date': datetime.datetime(2022, 5, 10, 20, 0),
#   'Sentiment_Score': 0.1932222222222222},
#  {'Ticker': 'MAR',
#   'Date': datetime.datetime(2022, 5, 10, 20, 0),
#   'Sentiment_Score': -0.019384693877551012},
#  {'Ticker': 'PWR',
#   'Date': datetime.datetime(2022, 5, 10, 20, 0),
#   'Sentiment_Score': 0.08196969696969696},
#  {'Ticker': 'MPRAU',
#   'Date': datetime.datetime(2022, 5, 10, 20, 0),
#   'Sentiment_Score': 0},
#  {'Ticker': 'POAI',
#   'Date': datetime.datetime(2022, 5, 10, 20, 0),
#   'Sentiment_Score': 0.33225897435897433},
#  {'Ticker': 'HGEN',
#   'Date': datetime.datetime(2022, 5, 10, 20, 0),
#   'Sentiment_Score': 0.04393902439024389},
#  {'Ticker': 'SBNY',
#   'Date': datetime.datetime(2022, 5, 10, 20, 0),
#   'Sentiment_Score': 0.239065},
#  {'Ticker': 'BKCC',
#   'Date': datetime.datetime(2022, 5, 10, 20, 0),
#   'Sentiment_Score': -0.028472222222222218},
#  {'Ticker': 'IVCB',
#   'Date': datetime.datetime(2022, 5, 10, 20, 0),
#   'Sentiment_Score': 0.2294},
#  {'Ticker': 'INSW',
#   'Date': datetime.datetime(2022, 5, 10, 20, 0),
#   'Sentiment_Score': 0.14574827586206893},
#  {'Ticker': 'SBTX',
#   'Date': datetime.datetime(2022, 5, 10, 20, 0),
#   'Sentiment_Score': 0.1591},
#  {'Ticker': 'CGABL',
#   'Date': datetime.datetime(2022, 5, 10, 20, 0),
#   'Sentiment_Score': -0.2732},
#  {'Ticker': 'CBRGW',
#   'Date': datetime.datetime(2022, 5, 10, 20, 0),
#   'Sentiment_Score': 0},
#  {'Ticker': 'BSM',
#   'Date': datetime.datetime(2022, 5, 10, 20, 0),
#   'Sentiment_Score': 0.054551999999999996},
#  {'Ticker': 'SHCRW',
#   'Date': datetime.datetime(2022, 5, 11, 8, 0),
#   'Sentiment_Score': 0},
#  {'Ticker': 'OEPWU',
#   'Date': datetime.datetime(2022, 5, 11, 8, 0),
#   'Sentiment_Score': 0},
#  {'Ticker': 'CREC',
#   'Date': datetime.datetime(2022, 5, 11, 8, 0),
#   'Sentiment_Score': -0.13225299999999998},
#  {'Ticker': 'KWR',
#   'Date': datetime.datetime(2022, 5, 11, 8, 0),
#   'Sentiment_Score': 0.016148484848484843},
#  {'Ticker': 'HORI',
#   'Date': datetime.datetime(2022, 5, 11, 8, 0),
#   'Sentiment_Score': 0.15738762886597937},
#  {'Ticker': 'ACLX',
#   'Date': datetime.datetime(2022, 5, 11, 8, 0),
#   'Sentiment_Score': 0.0024034482758620683},
#  {'Ticker': 'IMH',
#   'Date': datetime.datetime(2022, 5, 11, 8, 0),
#   'Sentiment_Score': 0.22606300000000004},
#  {'Ticker': 'WNC',
#   'Date': datetime.datetime(2022, 5, 11, 8, 0),
#   'Sentiment_Score': -0.23743100000000003},
#  {'Ticker': 'TRIP',
#   'Date': datetime.datetime(2022, 5, 11, 8, 0),
#   'Sentiment_Score': 0.2784948979591837},
#  {'Ticker': 'GBX',
#   'Date': datetime.datetime(2022, 5, 11, 8, 0),
#   'Sentiment_Score': 0.097272},
#  {'Ticker': 'AACI',
#   'Date': datetime.datetime(2022, 5, 11, 8, 0),
#   'Sentiment_Score': 0.036442857142857145},
#  {'Ticker': 'COSM',
#   'Date': datetime.datetime(2022, 5, 11, 8, 0),
#   'Sentiment_Score': 0.08423299999999999},
#  {'Ticker': 'SQ',
#   'Date': datetime.datetime(2022, 5, 11, 8, 0),
#   'Sentiment_Score': 0.149191},
#  {'Ticker': 'DOCU',
#   'Date': datetime.datetime(2022, 5, 11, 8, 0),
#   'Sentiment_Score': 0.019492929292929284},
#  {'Ticker': 'GRC',
#   'Date': datetime.datetime(2022, 5, 11, 8, 0),
#   'Sentiment_Score': 0.05982400000000001},
#  {'Ticker': 'FCT',
#   'Date': datetime.datetime(2022, 5, 11, 8, 0),
#   'Sentiment_Score': 0.091916},
#  {'Ticker': 'WEX',
#   'Date': datetime.datetime(2022, 5, 11, 8, 0),
#   'Sentiment_Score': 0.15853131313131313},
#  {'Ticker': 'DRQ',
#   'Date': datetime.datetime(2022, 5, 11, 8, 0),
#   'Sentiment_Score': 0.20495783132530127},
#  {'Ticker': 'MAR',
#   'Date': datetime.datetime(2022, 5, 11, 8, 0),
#   'Sentiment_Score': 0.068042},
#  {'Ticker': 'PWR',
#   'Date': datetime.datetime(2022, 5, 11, 8, 0),
#   'Sentiment_Score': 0.14742555555555556},
#  {'Ticker': 'MPRAU',
#   'Date': datetime.datetime(2022, 5, 11, 8, 0),
#   'Sentiment_Score': 0},
#  {'Ticker': 'POAI',
#   'Date': datetime.datetime(2022, 5, 11, 8, 0),
#   'Sentiment_Score': 0.3462265306122449},
#  {'Ticker': 'HGEN',
#   'Date': datetime.datetime(2022, 5, 11, 8, 0),
#   'Sentiment_Score': 0.05473518518518519},
#  {'Ticker': 'SBNY',
#   'Date': datetime.datetime(2022, 5, 11, 8, 0),
#   'Sentiment_Score': 0.16278518518518517},
#  {'Ticker': 'BKCC',
#   'Date': datetime.datetime(2022, 5, 11, 8, 0),
#   'Sentiment_Score': -0.011809999999999998},
#  {'Ticker': 'IVCB',
#   'Date': datetime.datetime(2022, 5, 11, 8, 0),
#   'Sentiment_Score': -0.01726666666666669},
#  {'Ticker': 'INSW',
#   'Date': datetime.datetime(2022, 5, 11, 8, 0),
#   'Sentiment_Score': 0.19328301886792457},
#  {'Ticker': 'SBTX',
#   'Date': datetime.datetime(2022, 5, 11, 8, 0),
#   'Sentiment_Score': 0.16455},
#  {'Ticker': 'CGABL',
#   'Date': datetime.datetime(2022, 5, 11, 8, 0),
#   'Sentiment_Score': -0.2732},
#  {'Ticker': 'CBRGW',
#   'Date': datetime.datetime(2022, 5, 11, 8, 0),
#   'Sentiment_Score': 0},
#  {'Ticker': 'BSM',
#   'Date': datetime.datetime(2022, 5, 11, 8, 0),
#   'Sentiment_Score': 0.06339799999999998},
#  {'Ticker': 'SHCRW',
#   'Date': datetime.datetime(2022, 5, 11, 12, 0),
#   'Sentiment_Score': 0},
#  {'Ticker': 'OEPWU',
#   'Date': datetime.datetime(2022, 5, 11, 12, 0),
#   'Sentiment_Score': 0},
#  {'Ticker': 'CREC',
#   'Date': datetime.datetime(2022, 5, 11, 12, 0),
#   'Sentiment_Score': -0.05674499999999999},
#  {'Ticker': 'KWR',
#   'Date': datetime.datetime(2022, 5, 11, 12, 0),
#   'Sentiment_Score': 0.03986458333333332},
#  {'Ticker': 'HORI',
#   'Date': datetime.datetime(2022, 5, 11, 12, 0),
#   'Sentiment_Score': 0.13279},
#  {'Ticker': 'ACLX',
#   'Date': datetime.datetime(2022, 5, 11, 12, 0),
#   'Sentiment_Score': 0.002248387096774193},
#  {'Ticker': 'IMH',
#   'Date': datetime.datetime(2022, 5, 11, 12, 0),
#   'Sentiment_Score': 0.14380909090909091},
#  {'Ticker': 'WNC',
#   'Date': datetime.datetime(2022, 5, 11, 12, 0),
#   'Sentiment_Score': -0.043163636363636355},
#  {'Ticker': 'TRIP',
#   'Date': datetime.datetime(2022, 5, 11, 12, 0),
#   'Sentiment_Score': 0.26069000000000003},
#  {'Ticker': 'GBX',
#   'Date': datetime.datetime(2022, 5, 11, 12, 0),
#   'Sentiment_Score': 0.089912},
#  {'Ticker': 'AACI',
#   'Date': datetime.datetime(2022, 5, 11, 12, 0),
#   'Sentiment_Score': 0.036442857142857145},
#  {'Ticker': 'COSM',
#   'Date': datetime.datetime(2022, 5, 11, 12, 0),
#   'Sentiment_Score': 0.08668400000000002},
#  {'Ticker': 'SQ',
#   'Date': datetime.datetime(2022, 5, 11, 12, 0),
#   'Sentiment_Score': 0.21980404040404042},
#  {'Ticker': 'DOCU',
#   'Date': datetime.datetime(2022, 5, 11, 12, 0),
#   'Sentiment_Score': -0.06671200000000001},
#  {'Ticker': 'GRC',
#   'Date': datetime.datetime(2022, 5, 11, 12, 0),
#   'Sentiment_Score': 0.107201},
#  {'Ticker': 'FCT',
#   'Date': datetime.datetime(2022, 5, 11, 12, 0),
#   'Sentiment_Score': 0.217399},
#  {'Ticker': 'WEX',
#   'Date': datetime.datetime(2022, 5, 11, 12, 0),
#   'Sentiment_Score': 0.08067777777777778},
#  {'Ticker': 'DRQ',
#   'Date': datetime.datetime(2022, 5, 11, 12, 0),
#   'Sentiment_Score': 0.1926691489361702},
#  {'Ticker': 'MAR',
#   'Date': datetime.datetime(2022, 5, 11, 12, 0),
#   'Sentiment_Score': -0.031585999999999996},
#  {'Ticker': 'PWR',
#   'Date': datetime.datetime(2022, 5, 11, 12, 0),
#   'Sentiment_Score': 0.103246},
#  {'Ticker': 'MPRAU',
#   'Date': datetime.datetime(2022, 5, 11, 12, 0),
#   'Sentiment_Score': 0},
#  {'Ticker': 'POAI',
#   'Date': datetime.datetime(2022, 5, 11, 12, 0),
#   'Sentiment_Score': 0.33264901960784315},
#  {'Ticker': 'HGEN',
#   'Date': datetime.datetime(2022, 5, 11, 12, 0),
#   'Sentiment_Score': 0.07901666666666668},
#  {'Ticker': 'SBNY',
#   'Date': datetime.datetime(2022, 5, 11, 12, 0),
#   'Sentiment_Score': 0.12968387096774195},
#  {'Ticker': 'BKCC',
#   'Date': datetime.datetime(2022, 5, 11, 12, 0),
#   'Sentiment_Score': -0.029751},
#  {'Ticker': 'IVCB',
#   'Date': datetime.datetime(2022, 5, 11, 12, 0),
#   'Sentiment_Score': -0.012950000000000017},
#  {'Ticker': 'INSW',
#   'Date': datetime.datetime(2022, 5, 11, 12, 0),
#   'Sentiment_Score': 0.15878450704225353},
#  {'Ticker': 'SBTX',
#   'Date': datetime.datetime(2022, 5, 11, 12, 0),
#   'Sentiment_Score': 0.16455},
#  {'Ticker': 'CGABL',
#   'Date': datetime.datetime(2022, 5, 11, 12, 0),
#   'Sentiment_Score': -0.2732},
#  {'Ticker': 'CBRGW',
#   'Date': datetime.datetime(2022, 5, 11, 12, 0),
#   'Sentiment_Score': 0},
#  {'Ticker': 'BSM',
#   'Date': datetime.datetime(2022, 5, 11, 12, 0),
#   'Sentiment_Score': -0.025410000000000002},
#  {'Ticker': 'SHCRW',
#   'Date': datetime.datetime(2022, 5, 11, 16, 0),
#   'Sentiment_Score': 0},
#  {'Ticker': 'OEPWU',
#   'Date': datetime.datetime(2022, 5, 11, 16, 0),
#   'Sentiment_Score': 0},
#  {'Ticker': 'CREC',
#   'Date': datetime.datetime(2022, 5, 11, 16, 0),
#   'Sentiment_Score': 0.042883000000000004},
#  {'Ticker': 'KWR',
#   'Date': datetime.datetime(2022, 5, 11, 16, 0),
#   'Sentiment_Score': 0.16761666666666666},
#  {'Ticker': 'HORI',
#   'Date': datetime.datetime(2022, 5, 11, 16, 0),
#   'Sentiment_Score': 0.03926428571428572},
#  {'Ticker': 'ACLX',
#   'Date': datetime.datetime(2022, 5, 11, 16, 0),
#   'Sentiment_Score': 0.019679411764705883},
#  {'Ticker': 'IMH',
#   'Date': datetime.datetime(2022, 5, 11, 16, 0),
#   'Sentiment_Score': 0.20731616161616162},
#  {'Ticker': 'WNC',
#   'Date': datetime.datetime(2022, 5, 11, 16, 0),
#   'Sentiment_Score': 0.17893399999999995},
#  {'Ticker': 'TRIP',
#   'Date': datetime.datetime(2022, 5, 11, 16, 0),
#   'Sentiment_Score': 0.21577199999999996},
#  {'Ticker': 'GBX',
#   'Date': datetime.datetime(2022, 5, 11, 16, 0),
#   'Sentiment_Score': 0.102459},
#  {'Ticker': 'AACI',
#   'Date': datetime.datetime(2022, 5, 11, 16, 0),
#   'Sentiment_Score': 0.08330833333333333},
#  {'Ticker': 'COSM',
#   'Date': datetime.datetime(2022, 5, 11, 16, 0),
#   'Sentiment_Score': 0.07775599999999999},
#  {'Ticker': 'SQ',
#   'Date': datetime.datetime(2022, 5, 11, 16, 0),
#   'Sentiment_Score': 0.068364},
#  {'Ticker': 'DOCU',
#   'Date': datetime.datetime(2022, 5, 11, 16, 0),
#   'Sentiment_Score': 0.018473000000000003},
#  {'Ticker': 'GRC',
#   'Date': datetime.datetime(2022, 5, 11, 16, 0),
#   'Sentiment_Score': 0.03941515151515152},
#  {'Ticker': 'FCT',
#   'Date': datetime.datetime(2022, 5, 11, 16, 0),
#   'Sentiment_Score': 0.111387},
#  {'Ticker': 'WEX',
#   'Date': datetime.datetime(2022, 5, 11, 16, 0),
#   'Sentiment_Score': 0.0784949494949495},
#  {'Ticker': 'DRQ',
#   'Date': datetime.datetime(2022, 5, 11, 16, 0),
#   'Sentiment_Score': 0.2184372340425532},
#  {'Ticker': 'MAR',
#   'Date': datetime.datetime(2022, 5, 11, 16, 0),
#   'Sentiment_Score': 0.0015214285714285716},
#  {'Ticker': 'PWR',
#   'Date': datetime.datetime(2022, 5, 11, 16, 0),
#   'Sentiment_Score': 0.0009424242424242407},
#  {'Ticker': 'MPRAU',
#   'Date': datetime.datetime(2022, 5, 11, 16, 0),
#   'Sentiment_Score': 0},
#  {'Ticker': 'POAI',
#   'Date': datetime.datetime(2022, 5, 11, 16, 0),
#   'Sentiment_Score': 0.3264163636363636},
#  {'Ticker': 'HGEN',
#   'Date': datetime.datetime(2022, 5, 11, 16, 0),
#   'Sentiment_Score': 0.055646666666666664},
#  {'Ticker': 'SBNY',
#   'Date': datetime.datetime(2022, 5, 11, 16, 0),
#   'Sentiment_Score': 0.1367425},
#  {'Ticker': 'BKCC',
#   'Date': datetime.datetime(2022, 5, 11, 16, 0),
#   'Sentiment_Score': -0.086037},
#  {'Ticker': 'IVCB',
#   'Date': datetime.datetime(2022, 5, 11, 16, 0),
#   'Sentiment_Score': -0.010360000000000013},
#  {'Ticker': 'INSW',
#   'Date': datetime.datetime(2022, 5, 11, 16, 0),
#   'Sentiment_Score': 0.16272692307692307},
#  {'Ticker': 'SBTX',
#   'Date': datetime.datetime(2022, 5, 11, 16, 0),
#   'Sentiment_Score': 0.14341666666666666},
#  {'Ticker': 'CGABL',
#   'Date': datetime.datetime(2022, 5, 11, 16, 0),
#   'Sentiment_Score': -0.2732},
#  {'Ticker': 'CBRGW',
#   'Date': datetime.datetime(2022, 5, 11, 16, 0),
#   'Sentiment_Score': 0},
#  {'Ticker': 'BSM',
#   'Date': datetime.datetime(2022, 5, 11, 16, 0),
#   'Sentiment_Score': 0.103147},
#  {'Ticker': 'SHCRW',
#   'Date': datetime.datetime(2022, 5, 11, 20, 0),
#   'Sentiment_Score': 0},
#  {'Ticker': 'OEPWU',
#   'Date': datetime.datetime(2022, 5, 11, 20, 0),
#   'Sentiment_Score': 0},
#  {'Ticker': 'CREC',
#   'Date': datetime.datetime(2022, 5, 11, 20, 0),
#   'Sentiment_Score': -0.067782},
#  {'Ticker': 'KWR',
#   'Date': datetime.datetime(2022, 5, 11, 20, 0),
#   'Sentiment_Score': 0.034943999999999996},
#  {'Ticker': 'HORI',
#   'Date': datetime.datetime(2022, 5, 11, 20, 0),
#   'Sentiment_Score': 0.06393979591836735},
#  {'Ticker': 'ACLX',
#   'Date': datetime.datetime(2022, 5, 11, 20, 0),
#   'Sentiment_Score': 0.019679411764705883},
#  {'Ticker': 'IMH',
#   'Date': datetime.datetime(2022, 5, 11, 20, 0),
#   'Sentiment_Score': 0.14987099999999998},
#  {'Ticker': 'WNC',
#   'Date': datetime.datetime(2022, 5, 11, 20, 0),
#   'Sentiment_Score': -0.228748},
#  {'Ticker': 'TRIP',
#   'Date': datetime.datetime(2022, 5, 11, 20, 0),
#   'Sentiment_Score': 0.211115625},
#  {'Ticker': 'GBX',
#   'Date': datetime.datetime(2022, 5, 11, 20, 0),
#   'Sentiment_Score': 0.08204},
#  {'Ticker': 'AACI',
#   'Date': datetime.datetime(2022, 5, 11, 20, 0),
#   'Sentiment_Score': 0.19962068965517243},
#  {'Ticker': 'COSM',
#   'Date': datetime.datetime(2022, 5, 11, 20, 0),
#   'Sentiment_Score': 0.09403099999999999},
#  {'Ticker': 'SQ',
#   'Date': datetime.datetime(2022, 5, 11, 20, 0),
#   'Sentiment_Score': 0.17472424242424245},
#  {'Ticker': 'DOCU',
#   'Date': datetime.datetime(2022, 5, 11, 20, 0),
#   'Sentiment_Score': 0.06025799999999999},
#  {'Ticker': 'GRC',
#   'Date': datetime.datetime(2022, 5, 11, 20, 0),
#   'Sentiment_Score': 0.016211999999999994},
#  {'Ticker': 'FCT',
#   'Date': datetime.datetime(2022, 5, 11, 20, 0),
#   'Sentiment_Score': 0.2370510204081632},
#  {'Ticker': 'WEX',
#   'Date': datetime.datetime(2022, 5, 11, 20, 0),
#   'Sentiment_Score': 0.13830101010101012},
#  {'Ticker': 'DRQ',
#   'Date': datetime.datetime(2022, 5, 11, 20, 0),
#   'Sentiment_Score': 0.2318863157894737},
#  {'Ticker': 'MAR',
#   'Date': datetime.datetime(2022, 5, 11, 20, 0),
#   'Sentiment_Score': -0.005885999999999998},
#  {'Ticker': 'PWR',
#   'Date': datetime.datetime(2022, 5, 11, 20, 0),
#   'Sentiment_Score': 0.09962727272727272},
#  {'Ticker': 'MPRAU',
#   'Date': datetime.datetime(2022, 5, 11, 20, 0),
#   'Sentiment_Score': 0},
#  {'Ticker': 'POAI',
#   'Date': datetime.datetime(2022, 5, 11, 20, 0),
#   'Sentiment_Score': 0.3052681818181818},
#  {'Ticker': 'HGEN',
#   'Date': datetime.datetime(2022, 5, 11, 20, 0),
#   'Sentiment_Score': 0.05343563218390805},
#  {'Ticker': 'SBNY',
#   'Date': datetime.datetime(2022, 5, 11, 20, 0),
#   'Sentiment_Score': 0.13722037037037038},
#  {'Ticker': 'BKCC',
#   'Date': datetime.datetime(2022, 5, 11, 20, 0),
#   'Sentiment_Score': -0.08995699999999998},
#  {'Ticker': 'IVCB',
#   'Date': datetime.datetime(2022, 5, 11, 20, 0),
#   'Sentiment_Score': -0.010360000000000013},
#  {'Ticker': 'INSW',
#   'Date': datetime.datetime(2022, 5, 11, 20, 0),
#   'Sentiment_Score': 0.15457590361445783},
#  {'Ticker': 'SBTX',
#   'Date': datetime.datetime(2022, 5, 11, 20, 0),
#   'Sentiment_Score': 0.09402857142857143},
#  {'Ticker': 'CGABL',
#   'Date': datetime.datetime(2022, 5, 11, 20, 0),
#   'Sentiment_Score': -0.2732},
#  {'Ticker': 'CBRGW',
#   'Date': datetime.datetime(2022, 5, 11, 20, 0),
#   'Sentiment_Score': 0},
#  {'Ticker': 'BSM',
#   'Date': datetime.datetime(2022, 5, 11, 20, 0),
#   'Sentiment_Score': 0.113015}]

# %%
## Do not touch
tweet_sentiments_all = []
tweet_sentiments_all.append(tweet_sentiments)

# %%
 #Second Call due to Twitter Rate Limits  
tweet_sentiments_2 = []
start_date = datetime(2022,5,12, 0,0,0)
end_date = datetime(2022,5,14, 0,0,0)

tweet_sentiments_2 = execute_tweet_sentiment_analysis(start_date, end_date)
# Out:
# Executing Tweet Analysis for SHCRW on 2022-05-12T08:00:00
# Executing Tweet Analysis for OEPWU on 2022-05-12T08:00:00
# Executing Tweet Analysis for CREC on 2022-05-12T08:00:00
# Executing Tweet Analysis for KWR on 2022-05-12T08:00:00
# Executing Tweet Analysis for HORI on 2022-05-12T08:00:00
# Executing Tweet Analysis for ACLX on 2022-05-12T08:00:00
# Executing Tweet Analysis for IMH on 2022-05-12T08:00:00
# Executing Tweet Analysis for WNC on 2022-05-12T08:00:00
# Executing Tweet Analysis for TRIP on 2022-05-12T08:00:00
# Executing Tweet Analysis for GBX on 2022-05-12T08:00:00
# Executing Tweet Analysis for AACI on 2022-05-12T08:00:00
# Executing Tweet Analysis for COSM on 2022-05-12T08:00:00
# Executing Tweet Analysis for SQ on 2022-05-12T08:00:00
# Executing Tweet Analysis for DOCU on 2022-05-12T08:00:00
# Executing Tweet Analysis for GRC on 2022-05-12T08:00:00
# Executing Tweet Analysis for FCT on 2022-05-12T08:00:00
# Executing Tweet Analysis for WEX on 2022-05-12T08:00:00
# Executing Tweet Analysis for DRQ on 2022-05-12T08:00:00
# Executing Tweet Analysis for MAR on 2022-05-12T08:00:00
# Executing Tweet Analysis for PWR on 2022-05-12T08:00:00
# Executing Tweet Analysis for MPRAU on 2022-05-12T08:00:00
# Executing Tweet Analysis for POAI on 2022-05-12T08:00:00
# Executing Tweet Analysis for HGEN on 2022-05-12T08:00:00
# Executing Tweet Analysis for SBNY on 2022-05-12T08:00:00
# Executing Tweet Analysis for BKCC on 2022-05-12T08:00:00
# Executing Tweet Analysis for IVCB on 2022-05-12T08:00:00
# Executing Tweet Analysis for INSW on 2022-05-12T08:00:00
# Executing Tweet Analysis for SBTX on 2022-05-12T08:00:00
# Executing Tweet Analysis for CGABL on 2022-05-12T08:00:00
# Executing Tweet Analysis for CBRGW on 2022-05-12T08:00:00
# Executing Tweet Analysis for BSM on 2022-05-12T08:00:00
# Executing Tweet Analysis for SHCRW on 2022-05-12T12:00:00
# Executing Tweet Analysis for OEPWU on 2022-05-12T12:00:00
# Executing Tweet Analysis for CREC on 2022-05-12T12:00:00
# Executing Tweet Analysis for KWR on 2022-05-12T12:00:00
# Executing Tweet Analysis for HORI on 2022-05-12T12:00:00
# Executing Tweet Analysis for ACLX on 2022-05-12T12:00:00
# Executing Tweet Analysis for IMH on 2022-05-12T12:00:00
# Executing Tweet Analysis for WNC on 2022-05-12T12:00:00
# Executing Tweet Analysis for TRIP on 2022-05-12T12:00:00
# Executing Tweet Analysis for GBX on 2022-05-12T12:00:00
# Executing Tweet Analysis for AACI on 2022-05-12T12:00:00
# Executing Tweet Analysis for COSM on 2022-05-12T12:00:00
# Executing Tweet Analysis for SQ on 2022-05-12T12:00:00
# Executing Tweet Analysis for DOCU on 2022-05-12T12:00:00
# Executing Tweet Analysis for GRC on 2022-05-12T12:00:00
# Executing Tweet Analysis for FCT on 2022-05-12T12:00:00
# Executing Tweet Analysis for WEX on 2022-05-12T12:00:00
# Executing Tweet Analysis for DRQ on 2022-05-12T12:00:00
# Executing Tweet Analysis for MAR on 2022-05-12T12:00:00
# Executing Tweet Analysis for PWR on 2022-05-12T12:00:00
# Executing Tweet Analysis for MPRAU on 2022-05-12T12:00:00
# Executing Tweet Analysis for POAI on 2022-05-12T12:00:00
# Executing Tweet Analysis for HGEN on 2022-05-12T12:00:00
# Executing Tweet Analysis for SBNY on 2022-05-12T12:00:00
# Executing Tweet Analysis for BKCC on 2022-05-12T12:00:00
# Executing Tweet Analysis for IVCB on 2022-05-12T12:00:00
# Executing Tweet Analysis for INSW on 2022-05-12T12:00:00
# Executing Tweet Analysis for SBTX on 2022-05-12T12:00:00
# Executing Tweet Analysis for CGABL on 2022-05-12T12:00:00
# Executing Tweet Analysis for CBRGW on 2022-05-12T12:00:00
# Executing Tweet Analysis for BSM on 2022-05-12T12:00:00
# Executing Tweet Analysis for SHCRW on 2022-05-12T16:00:00
# Executing Tweet Analysis for OEPWU on 2022-05-12T16:00:00
# Executing Tweet Analysis for CREC on 2022-05-12T16:00:00
# Executing Tweet Analysis for KWR on 2022-05-12T16:00:00
# Executing Tweet Analysis for HORI on 2022-05-12T16:00:00
# Executing Tweet Analysis for ACLX on 2022-05-12T16:00:00
# Executing Tweet Analysis for IMH on 2022-05-12T16:00:00
# Executing Tweet Analysis for WNC on 2022-05-12T16:00:00
# Executing Tweet Analysis for TRIP on 2022-05-12T16:00:00
# Executing Tweet Analysis for GBX on 2022-05-12T16:00:00
# Executing Tweet Analysis for AACI on 2022-05-12T16:00:00
# Executing Tweet Analysis for COSM on 2022-05-12T16:00:00
# Executing Tweet Analysis for SQ on 2022-05-12T16:00:00
# Executing Tweet Analysis for DOCU on 2022-05-12T16:00:00
# Executing Tweet Analysis for GRC on 2022-05-12T16:00:00
# Executing Tweet Analysis for FCT on 2022-05-12T16:00:00
# Executing Tweet Analysis for WEX on 2022-05-12T16:00:00
# Executing Tweet Analysis for DRQ on 2022-05-12T16:00:00
# Executing Tweet Analysis for MAR on 2022-05-12T16:00:00
# Executing Tweet Analysis for PWR on 2022-05-12T16:00:00
# Executing Tweet Analysis for MPRAU on 2022-05-12T16:00:00
# Executing Tweet Analysis for POAI on 2022-05-12T16:00:00
# Executing Tweet Analysis for HGEN on 2022-05-12T16:00:00
# Executing Tweet Analysis for SBNY on 2022-05-12T16:00:00
# Executing Tweet Analysis for BKCC on 2022-05-12T16:00:00
# Executing Tweet Analysis for IVCB on 2022-05-12T16:00:00
# Executing Tweet Analysis for INSW on 2022-05-12T16:00:00
# Executing Tweet Analysis for SBTX on 2022-05-12T16:00:00
# Executing Tweet Analysis for CGABL on 2022-05-12T16:00:00
# Executing Tweet Analysis for CBRGW on 2022-05-12T16:00:00
# Executing Tweet Analysis for BSM on 2022-05-12T16:00:00
# Executing Tweet Analysis for SHCRW on 2022-05-12T20:00:00
# Executing Tweet Analysis for OEPWU on 2022-05-12T20:00:00
# Executing Tweet Analysis for CREC on 2022-05-12T20:00:00
# Executing Tweet Analysis for KWR on 2022-05-12T20:00:00
# Executing Tweet Analysis for HORI on 2022-05-12T20:00:00
# Executing Tweet Analysis for ACLX on 2022-05-12T20:00:00
# Executing Tweet Analysis for IMH on 2022-05-12T20:00:00
# Executing Tweet Analysis for WNC on 2022-05-12T20:00:00
# Executing Tweet Analysis for TRIP on 2022-05-12T20:00:00
# Executing Tweet Analysis for GBX on 2022-05-12T20:00:00
# Executing Tweet Analysis for AACI on 2022-05-12T20:00:00
# Executing Tweet Analysis for COSM on 2022-05-12T20:00:00
# Executing Tweet Analysis for SQ on 2022-05-12T20:00:00
# Executing Tweet Analysis for DOCU on 2022-05-12T20:00:00
# Executing Tweet Analysis for GRC on 2022-05-12T20:00:00
# Executing Tweet Analysis for FCT on 2022-05-12T20:00:00
# Executing Tweet Analysis for WEX on 2022-05-12T20:00:00
# Executing Tweet Analysis for DRQ on 2022-05-12T20:00:00
# Executing Tweet Analysis for MAR on 2022-05-12T20:00:00
# Executing Tweet Analysis for PWR on 2022-05-12T20:00:00
# Executing Tweet Analysis for MPRAU on 2022-05-12T20:00:00
# Executing Tweet Analysis for POAI on 2022-05-12T20:00:00
# Executing Tweet Analysis for HGEN on 2022-05-12T20:00:00
# Executing Tweet Analysis for SBNY on 2022-05-12T20:00:00
# Executing Tweet Analysis for BKCC on 2022-05-12T20:00:00
# Executing Tweet Analysis for IVCB on 2022-05-12T20:00:00
# Executing Tweet Analysis for INSW on 2022-05-12T20:00:00
# Executing Tweet Analysis for SBTX on 2022-05-12T20:00:00
# Executing Tweet Analysis for CGABL on 2022-05-12T20:00:00
# Executing Tweet Analysis for CBRGW on 2022-05-12T20:00:00
# Executing Tweet Analysis for BSM on 2022-05-12T20:00:00
# Executing Tweet Analysis for SHCRW on 2022-05-13T08:00:00
# Executing Tweet Analysis for OEPWU on 2022-05-13T08:00:00
# Executing Tweet Analysis for CREC on 2022-05-13T08:00:00
# Executing Tweet Analysis for KWR on 2022-05-13T08:00:00
# Executing Tweet Analysis for HORI on 2022-05-13T08:00:00
# Executing Tweet Analysis for ACLX on 2022-05-13T08:00:00
# Executing Tweet Analysis for IMH on 2022-05-13T08:00:00
# Executing Tweet Analysis for WNC on 2022-05-13T08:00:00
# Executing Tweet Analysis for TRIP on 2022-05-13T08:00:00
# Executing Tweet Analysis for GBX on 2022-05-13T08:00:00
# Executing Tweet Analysis for AACI on 2022-05-13T08:00:00
# Executing Tweet Analysis for COSM on 2022-05-13T08:00:00
# Executing Tweet Analysis for SQ on 2022-05-13T08:00:00
# Executing Tweet Analysis for DOCU on 2022-05-13T08:00:00
# Executing Tweet Analysis for GRC on 2022-05-13T08:00:00
# Executing Tweet Analysis for FCT on 2022-05-13T08:00:00
# Executing Tweet Analysis for WEX on 2022-05-13T08:00:00
# Executing Tweet Analysis for DRQ on 2022-05-13T08:00:00
# Executing Tweet Analysis for MAR on 2022-05-13T08:00:00
# Executing Tweet Analysis for PWR on 2022-05-13T08:00:00
# Executing Tweet Analysis for MPRAU on 2022-05-13T08:00:00
# Executing Tweet Analysis for POAI on 2022-05-13T08:00:00
# Executing Tweet Analysis for HGEN on 2022-05-13T08:00:00
# Executing Tweet Analysis for SBNY on 2022-05-13T08:00:00
# Executing Tweet Analysis for BKCC on 2022-05-13T08:00:00
# Executing Tweet Analysis for IVCB on 2022-05-13T08:00:00
# Executing Tweet Analysis for INSW on 2022-05-13T08:00:00
# Executing Tweet Analysis for SBTX on 2022-05-13T08:00:00
# Executing Tweet Analysis for CGABL on 2022-05-13T08:00:00
# Executing Tweet Analysis for CBRGW on 2022-05-13T08:00:00
# Executing Tweet Analysis for BSM on 2022-05-13T08:00:00
# Executing Tweet Analysis for SHCRW on 2022-05-13T12:00:00
# Executing Tweet Analysis for OEPWU on 2022-05-13T12:00:00
# Executing Tweet Analysis for CREC on 2022-05-13T12:00:00
# Executing Tweet Analysis for KWR on 2022-05-13T12:00:00
# Executing Tweet Analysis for HORI on 2022-05-13T12:00:00
# Executing Tweet Analysis for ACLX on 2022-05-13T12:00:00
# Executing Tweet Analysis for IMH on 2022-05-13T12:00:00
# Executing Tweet Analysis for WNC on 2022-05-13T12:00:00
# Executing Tweet Analysis for TRIP on 2022-05-13T12:00:00
# Executing Tweet Analysis for GBX on 2022-05-13T12:00:00
# Executing Tweet Analysis for AACI on 2022-05-13T12:00:00
# Executing Tweet Analysis for COSM on 2022-05-13T12:00:00
# Executing Tweet Analysis for SQ on 2022-05-13T12:00:00
# Executing Tweet Analysis for DOCU on 2022-05-13T12:00:00
# Executing Tweet Analysis for GRC on 2022-05-13T12:00:00
# Executing Tweet Analysis for FCT on 2022-05-13T12:00:00
# Executing Tweet Analysis for WEX on 2022-05-13T12:00:00
# Executing Tweet Analysis for DRQ on 2022-05-13T12:00:00
# Executing Tweet Analysis for MAR on 2022-05-13T12:00:00
# Executing Tweet Analysis for PWR on 2022-05-13T12:00:00
# Executing Tweet Analysis for MPRAU on 2022-05-13T12:00:00
# Executing Tweet Analysis for POAI on 2022-05-13T12:00:00
# Executing Tweet Analysis for HGEN on 2022-05-13T12:00:00
# Executing Tweet Analysis for SBNY on 2022-05-13T12:00:00
# Executing Tweet Analysis for BKCC on 2022-05-13T12:00:00
# Executing Tweet Analysis for IVCB on 2022-05-13T12:00:00
# Executing Tweet Analysis for INSW on 2022-05-13T12:00:00
# Executing Tweet Analysis for SBTX on 2022-05-13T12:00:00
# Executing Tweet Analysis for CGABL on 2022-05-13T12:00:00
# Executing Tweet Analysis for CBRGW on 2022-05-13T12:00:00
# Executing Tweet Analysis for BSM on 2022-05-13T12:00:00
# Executing Tweet Analysis for SHCRW on 2022-05-13T16:00:00
# Executing Tweet Analysis for OEPWU on 2022-05-13T16:00:00
# Executing Tweet Analysis for CREC on 2022-05-13T16:00:00
# Executing Tweet Analysis for KWR on 2022-05-13T16:00:00
# Executing Tweet Analysis for HORI on 2022-05-13T16:00:00
# Executing Tweet Analysis for ACLX on 2022-05-13T16:00:00
# Executing Tweet Analysis for IMH on 2022-05-13T16:00:00
# Executing Tweet Analysis for WNC on 2022-05-13T16:00:00
# Executing Tweet Analysis for TRIP on 2022-05-13T16:00:00
# Executing Tweet Analysis for GBX on 2022-05-13T16:00:00
# Executing Tweet Analysis for AACI on 2022-05-13T16:00:00
# Executing Tweet Analysis for COSM on 2022-05-13T16:00:00
# Executing Tweet Analysis for SQ on 2022-05-13T16:00:00
# Executing Tweet Analysis for DOCU on 2022-05-13T16:00:00
# Executing Tweet Analysis for GRC on 2022-05-13T16:00:00
# Executing Tweet Analysis for FCT on 2022-05-13T16:00:00
# Executing Tweet Analysis for WEX on 2022-05-13T16:00:00
# Executing Tweet Analysis for DRQ on 2022-05-13T16:00:00
# Executing Tweet Analysis for MAR on 2022-05-13T16:00:00
# Executing Tweet Analysis for PWR on 2022-05-13T16:00:00
# Executing Tweet Analysis for MPRAU on 2022-05-13T16:00:00
# Executing Tweet Analysis for POAI on 2022-05-13T16:00:00
# Executing Tweet Analysis for HGEN on 2022-05-13T16:00:00
# Executing Tweet Analysis for SBNY on 2022-05-13T16:00:00
# Executing Tweet Analysis for BKCC on 2022-05-13T16:00:00
# Executing Tweet Analysis for IVCB on 2022-05-13T16:00:00
# Executing Tweet Analysis for INSW on 2022-05-13T16:00:00
# Executing Tweet Analysis for SBTX on 2022-05-13T16:00:00
# Executing Tweet Analysis for CGABL on 2022-05-13T16:00:00
# Executing Tweet Analysis for CBRGW on 2022-05-13T16:00:00
# Executing Tweet Analysis for BSM on 2022-05-13T16:00:00
# Executing Tweet Analysis for SHCRW on 2022-05-13T20:00:00
# Executing Tweet Analysis for OEPWU on 2022-05-13T20:00:00
# Executing Tweet Analysis for CREC on 2022-05-13T20:00:00
# Executing Tweet Analysis for KWR on 2022-05-13T20:00:00
# Executing Tweet Analysis for HORI on 2022-05-13T20:00:00
# Executing Tweet Analysis for ACLX on 2022-05-13T20:00:00
# Executing Tweet Analysis for IMH on 2022-05-13T20:00:00
# Executing Tweet Analysis for WNC on 2022-05-13T20:00:00
# Executing Tweet Analysis for TRIP on 2022-05-13T20:00:00
# Executing Tweet Analysis for GBX on 2022-05-13T20:00:00
# Executing Tweet Analysis for AACI on 2022-05-13T20:00:00
# Executing Tweet Analysis for COSM on 2022-05-13T20:00:00
# Executing Tweet Analysis for SQ on 2022-05-13T20:00:00
# Executing Tweet Analysis for DOCU on 2022-05-13T20:00:00
# Executing Tweet Analysis for GRC on 2022-05-13T20:00:00
# Executing Tweet Analysis for FCT on 2022-05-13T20:00:00
# Executing Tweet Analysis for WEX on 2022-05-13T20:00:00
# Executing Tweet Analysis for DRQ on 2022-05-13T20:00:00
# Executing Tweet Analysis for MAR on 2022-05-13T20:00:00
# Executing Tweet Analysis for PWR on 2022-05-13T20:00:00
# Executing Tweet Analysis for MPRAU on 2022-05-13T20:00:00
# Executing Tweet Analysis for POAI on 2022-05-13T20:00:00
# Executing Tweet Analysis for HGEN on 2022-05-13T20:00:00
# Executing Tweet Analysis for SBNY on 2022-05-13T20:00:00
# Executing Tweet Analysis for BKCC on 2022-05-13T20:00:00
# Executing Tweet Analysis for IVCB on 2022-05-13T20:00:00
# Executing Tweet Analysis for INSW on 2022-05-13T20:00:00
# Executing Tweet Analysis for SBTX on 2022-05-13T20:00:00
# Executing Tweet Analysis for CGABL on 2022-05-13T20:00:00
# Executing Tweet Analysis for CBRGW on 2022-05-13T20:00:00
# Executing Tweet Analysis for BSM on 2022-05-13T20:00:00

# %%
 #Third Call due to Twitter Rate Limits  
tweet_sentiments_3 = []
start_date = datetime(2022,5,14, 0,0,0)
end_date = datetime(2022,5,15, 0,0,0)

tweet_sentiments_3 = execute_tweet_sentiment_analysis(start_date, end_date)

# %%
# Out:
# Executing Tweet Analysis for SHCRW on 2022-05-14T08:00:00
# Executing Tweet Analysis for OEPWU on 2022-05-14T08:00:00
# Executing Tweet Analysis for CREC on 2022-05-14T08:00:00
# Executing Tweet Analysis for KWR on 2022-05-14T08:00:00
# Executing Tweet Analysis for HORI on 2022-05-14T08:00:00
# Executing Tweet Analysis for ACLX on 2022-05-14T08:00:00
# Executing Tweet Analysis for IMH on 2022-05-14T08:00:00
# Executing Tweet Analysis for WNC on 2022-05-14T08:00:00
# Executing Tweet Analysis for TRIP on 2022-05-14T08:00:00
# Executing Tweet Analysis for GBX on 2022-05-14T08:00:00
# Executing Tweet Analysis for AACI on 2022-05-14T08:00:00
# Executing Tweet Analysis for COSM on 2022-05-14T08:00:00
# Executing Tweet Analysis for SQ on 2022-05-14T08:00:00
# Executing Tweet Analysis for DOCU on 2022-05-14T08:00:00
# Executing Tweet Analysis for GRC on 2022-05-14T08:00:00
# Executing Tweet Analysis for FCT on 2022-05-14T08:00:00
# Executing Tweet Analysis for WEX on 2022-05-14T08:00:00
# Executing Tweet Analysis for DRQ on 2022-05-14T08:00:00
# Executing Tweet Analysis for MAR on 2022-05-14T08:00:00
# Executing Tweet Analysis for PWR on 2022-05-14T08:00:00
# Executing Tweet Analysis for MPRAU on 2022-05-14T08:00:00
# Executing Tweet Analysis for POAI on 2022-05-14T08:00:00
# Executing Tweet Analysis for HGEN on 2022-05-14T08:00:00
# Executing Tweet Analysis for SBNY on 2022-05-14T08:00:00
# Executing Tweet Analysis for BKCC on 2022-05-14T08:00:00
# Executing Tweet Analysis for IVCB on 2022-05-14T08:00:00
# Executing Tweet Analysis for INSW on 2022-05-14T08:00:00
# Executing Tweet Analysis for SBTX on 2022-05-14T08:00:00
# Executing Tweet Analysis for CGABL on 2022-05-14T08:00:00
# Executing Tweet Analysis for CBRGW on 2022-05-14T08:00:00
# Executing Tweet Analysis for BSM on 2022-05-14T08:00:00
# Executing Tweet Analysis for SHCRW on 2022-05-14T12:00:00
# Executing Tweet Analysis for OEPWU on 2022-05-14T12:00:00
# Executing Tweet Analysis for CREC on 2022-05-14T12:00:00
# Executing Tweet Analysis for KWR on 2022-05-14T12:00:00
# Executing Tweet Analysis for HORI on 2022-05-14T12:00:00
# Executing Tweet Analysis for ACLX on 2022-05-14T12:00:00
# Executing Tweet Analysis for IMH on 2022-05-14T12:00:00
# Executing Tweet Analysis for WNC on 2022-05-14T12:00:00
# Executing Tweet Analysis for TRIP on 2022-05-14T12:00:00
# Executing Tweet Analysis for GBX on 2022-05-14T12:00:00
# Executing Tweet Analysis for AACI on 2022-05-14T12:00:00
# Executing Tweet Analysis for COSM on 2022-05-14T12:00:00
# Executing Tweet Analysis for SQ on 2022-05-14T12:00:00
# Executing Tweet Analysis for DOCU on 2022-05-14T12:00:00
# Executing Tweet Analysis for GRC on 2022-05-14T12:00:00
# Executing Tweet Analysis for FCT on 2022-05-14T12:00:00
# Executing Tweet Analysis for WEX on 2022-05-14T12:00:00
# Executing Tweet Analysis for DRQ on 2022-05-14T12:00:00
# Executing Tweet Analysis for MAR on 2022-05-14T12:00:00
# Executing Tweet Analysis for PWR on 2022-05-14T12:00:00
# Executing Tweet Analysis for MPRAU on 2022-05-14T12:00:00
# Executing Tweet Analysis for POAI on 2022-05-14T12:00:00
# Executing Tweet Analysis for HGEN on 2022-05-14T12:00:00
# Executing Tweet Analysis for SBNY on 2022-05-14T12:00:00
# Executing Tweet Analysis for BKCC on 2022-05-14T12:00:00
# Executing Tweet Analysis for IVCB on 2022-05-14T12:00:00
# Executing Tweet Analysis for INSW on 2022-05-14T12:00:00
# Executing Tweet Analysis for SBTX on 2022-05-14T12:00:00
# Executing Tweet Analysis for CGABL on 2022-05-14T12:00:00
# Executing Tweet Analysis for CBRGW on 2022-05-14T12:00:00
# Executing Tweet Analysis for BSM on 2022-05-14T12:00:00
# Executing Tweet Analysis for SHCRW on 2022-05-14T16:00:00
# Executing Tweet Analysis for OEPWU on 2022-05-14T16:00:00
# Executing Tweet Analysis for CREC on 2022-05-14T16:00:00
# Executing Tweet Analysis for KWR on 2022-05-14T16:00:00
# Executing Tweet Analysis for HORI on 2022-05-14T16:00:00
# Executing Tweet Analysis for ACLX on 2022-05-14T16:00:00
# Executing Tweet Analysis for IMH on 2022-05-14T16:00:00
# Executing Tweet Analysis for WNC on 2022-05-14T16:00:00
# Executing Tweet Analysis for TRIP on 2022-05-14T16:00:00
# Executing Tweet Analysis for GBX on 2022-05-14T16:00:00
# Executing Tweet Analysis for AACI on 2022-05-14T16:00:00
# Executing Tweet Analysis for COSM on 2022-05-14T16:00:00
# Executing Tweet Analysis for SQ on 2022-05-14T16:00:00
# Executing Tweet Analysis for DOCU on 2022-05-14T16:00:00
# Executing Tweet Analysis for GRC on 2022-05-14T16:00:00
# Executing Tweet Analysis for FCT on 2022-05-14T16:00:00
# Executing Tweet Analysis for WEX on 2022-05-14T16:00:00
# Executing Tweet Analysis for DRQ on 2022-05-14T16:00:00
# Executing Tweet Analysis for MAR on 2022-05-14T16:00:00
# Executing Tweet Analysis for PWR on 2022-05-14T16:00:00
# Executing Tweet Analysis for MPRAU on 2022-05-14T16:00:00
# Executing Tweet Analysis for POAI on 2022-05-14T16:00:00
# Executing Tweet Analysis for HGEN on 2022-05-14T16:00:00
# Executing Tweet Analysis for SBNY on 2022-05-14T16:00:00
# Executing Tweet Analysis for BKCC on 2022-05-14T16:00:00
# Executing Tweet Analysis for IVCB on 2022-05-14T16:00:00
# Executing Tweet Analysis for INSW on 2022-05-14T16:00:00
# Executing Tweet Analysis for SBTX on 2022-05-14T16:00:00
# Executing Tweet Analysis for CGABL on 2022-05-14T16:00:00
# Executing Tweet Analysis for CBRGW on 2022-05-14T16:00:00
# Executing Tweet Analysis for BSM on 2022-05-14T16:00:00
# Executing Tweet Analysis for SHCRW on 2022-05-14T20:00:00
# Executing Tweet Analysis for OEPWU on 2022-05-14T20:00:00
# Executing Tweet Analysis for CREC on 2022-05-14T20:00:00
# Executing Tweet Analysis for KWR on 2022-05-14T20:00:00
# Executing Tweet Analysis for HORI on 2022-05-14T20:00:00
# Executing Tweet Analysis for ACLX on 2022-05-14T20:00:00
# Executing Tweet Analysis for IMH on 2022-05-14T20:00:00
# Executing Tweet Analysis for WNC on 2022-05-14T20:00:00
# Executing Tweet Analysis for TRIP on 2022-05-14T20:00:00
# Executing Tweet Analysis for GBX on 2022-05-14T20:00:00
# Executing Tweet Analysis for AACI on 2022-05-14T20:00:00
# Executing Tweet Analysis for COSM on 2022-05-14T20:00:00
# Executing Tweet Analysis for SQ on 2022-05-14T20:00:00
# Executing Tweet Analysis for DOCU on 2022-05-14T20:00:00
# Executing Tweet Analysis for GRC on 2022-05-14T20:00:00
# Executing Tweet Analysis for FCT on 2022-05-14T20:00:00
# Executing Tweet Analysis for WEX on 2022-05-14T20:00:00
# Executing Tweet Analysis for DRQ on 2022-05-14T20:00:00
# Executing Tweet Analysis for MAR on 2022-05-14T20:00:00
# Executing Tweet Analysis for PWR on 2022-05-14T20:00:00
# Executing Tweet Analysis for MPRAU on 2022-05-14T20:00:00
# Executing Tweet Analysis for POAI on 2022-05-14T20:00:00
# Executing Tweet Analysis for HGEN on 2022-05-14T20:00:00
# Executing Tweet Analysis for SBNY on 2022-05-14T20:00:00
# Executing Tweet Analysis for BKCC on 2022-05-14T20:00:00
# Executing Tweet Analysis for IVCB on 2022-05-14T20:00:00
# Executing Tweet Analysis for INSW on 2022-05-14T20:00:00
# Executing Tweet Analysis for SBTX on 2022-05-14T20:00:00
# Executing Tweet Analysis for CGABL on 2022-05-14T20:00:00
# Executing Tweet Analysis for CBRGW on 2022-05-14T20:00:00
# Executing Tweet Analysis for BSM on 2022-05-14T20:00:00

# %%
 #Fourth Call due to Twitter Rate Limits  
tweet_sentiments_4 = []
start_date = datetime(2022,5,15, 0,0,0)
end_date = datetime(2022,5,16, 0,0,0)

tweet_sentiments_4 = execute_tweet_sentiment_analysis(start_date, end_date)
# Out:
# Executing Tweet Analysis for SHCRW on 2022-05-15T08:00:00
# Executing Tweet Analysis for OEPWU on 2022-05-15T08:00:00
# Executing Tweet Analysis for CREC on 2022-05-15T08:00:00
# Executing Tweet Analysis for KWR on 2022-05-15T08:00:00
# Executing Tweet Analysis for HORI on 2022-05-15T08:00:00
# Executing Tweet Analysis for ACLX on 2022-05-15T08:00:00
# Executing Tweet Analysis for IMH on 2022-05-15T08:00:00
# Executing Tweet Analysis for WNC on 2022-05-15T08:00:00
# Executing Tweet Analysis for TRIP on 2022-05-15T08:00:00
# Executing Tweet Analysis for GBX on 2022-05-15T08:00:00
# Executing Tweet Analysis for AACI on 2022-05-15T08:00:00
# Executing Tweet Analysis for COSM on 2022-05-15T08:00:00
# Executing Tweet Analysis for SQ on 2022-05-15T08:00:00
# Executing Tweet Analysis for DOCU on 2022-05-15T08:00:00
# Executing Tweet Analysis for GRC on 2022-05-15T08:00:00
# Executing Tweet Analysis for FCT on 2022-05-15T08:00:00
# Executing Tweet Analysis for WEX on 2022-05-15T08:00:00
# Executing Tweet Analysis for DRQ on 2022-05-15T08:00:00
# Executing Tweet Analysis for MAR on 2022-05-15T08:00:00
# Executing Tweet Analysis for PWR on 2022-05-15T08:00:00
# Executing Tweet Analysis for MPRAU on 2022-05-15T08:00:00
# Executing Tweet Analysis for POAI on 2022-05-15T08:00:00
# Executing Tweet Analysis for HGEN on 2022-05-15T08:00:00
# Executing Tweet Analysis for SBNY on 2022-05-15T08:00:00
# Executing Tweet Analysis for BKCC on 2022-05-15T08:00:00
# Executing Tweet Analysis for IVCB on 2022-05-15T08:00:00
# Executing Tweet Analysis for INSW on 2022-05-15T08:00:00
# Executing Tweet Analysis for SBTX on 2022-05-15T08:00:00
# Executing Tweet Analysis for CGABL on 2022-05-15T08:00:00
# Executing Tweet Analysis for CBRGW on 2022-05-15T08:00:00
# Executing Tweet Analysis for BSM on 2022-05-15T08:00:00
# Executing Tweet Analysis for SHCRW on 2022-05-15T12:00:00
# Executing Tweet Analysis for OEPWU on 2022-05-15T12:00:00
# Executing Tweet Analysis for CREC on 2022-05-15T12:00:00
# Executing Tweet Analysis for KWR on 2022-05-15T12:00:00
# Executing Tweet Analysis for HORI on 2022-05-15T12:00:00
# Executing Tweet Analysis for ACLX on 2022-05-15T12:00:00
# Executing Tweet Analysis for IMH on 2022-05-15T12:00:00
# Executing Tweet Analysis for WNC on 2022-05-15T12:00:00
# Executing Tweet Analysis for TRIP on 2022-05-15T12:00:00
# Executing Tweet Analysis for GBX on 2022-05-15T12:00:00
# Executing Tweet Analysis for AACI on 2022-05-15T12:00:00
# Executing Tweet Analysis for COSM on 2022-05-15T12:00:00
# Executing Tweet Analysis for SQ on 2022-05-15T12:00:00
# Executing Tweet Analysis for DOCU on 2022-05-15T12:00:00
# Executing Tweet Analysis for GRC on 2022-05-15T12:00:00
# Executing Tweet Analysis for FCT on 2022-05-15T12:00:00
# Executing Tweet Analysis for WEX on 2022-05-15T12:00:00
# Executing Tweet Analysis for DRQ on 2022-05-15T12:00:00
# Executing Tweet Analysis for MAR on 2022-05-15T12:00:00
# Executing Tweet Analysis for PWR on 2022-05-15T12:00:00
# Executing Tweet Analysis for MPRAU on 2022-05-15T12:00:00
# Executing Tweet Analysis for POAI on 2022-05-15T12:00:00
# Executing Tweet Analysis for HGEN on 2022-05-15T12:00:00
# Executing Tweet Analysis for SBNY on 2022-05-15T12:00:00
# Executing Tweet Analysis for BKCC on 2022-05-15T12:00:00
# Executing Tweet Analysis for IVCB on 2022-05-15T12:00:00
# Executing Tweet Analysis for INSW on 2022-05-15T12:00:00
# Executing Tweet Analysis for SBTX on 2022-05-15T12:00:00
# Executing Tweet Analysis for CGABL on 2022-05-15T12:00:00
# Executing Tweet Analysis for CBRGW on 2022-05-15T12:00:00
# Executing Tweet Analysis for BSM on 2022-05-15T12:00:00
# Executing Tweet Analysis for SHCRW on 2022-05-15T16:00:00
# Executing Tweet Analysis for OEPWU on 2022-05-15T16:00:00
# Executing Tweet Analysis for CREC on 2022-05-15T16:00:00
# Executing Tweet Analysis for KWR on 2022-05-15T16:00:00
# Executing Tweet Analysis for HORI on 2022-05-15T16:00:00
# Executing Tweet Analysis for ACLX on 2022-05-15T16:00:00
# Executing Tweet Analysis for IMH on 2022-05-15T16:00:00
# Executing Tweet Analysis for WNC on 2022-05-15T16:00:00
# Executing Tweet Analysis for TRIP on 2022-05-15T16:00:00
# Executing Tweet Analysis for GBX on 2022-05-15T16:00:00
# Executing Tweet Analysis for AACI on 2022-05-15T16:00:00
# Executing Tweet Analysis for COSM on 2022-05-15T16:00:00
# Executing Tweet Analysis for SQ on 2022-05-15T16:00:00
# Executing Tweet Analysis for DOCU on 2022-05-15T16:00:00
# Executing Tweet Analysis for GRC on 2022-05-15T16:00:00
# Executing Tweet Analysis for FCT on 2022-05-15T16:00:00
# Executing Tweet Analysis for WEX on 2022-05-15T16:00:00
# Executing Tweet Analysis for DRQ on 2022-05-15T16:00:00
# Executing Tweet Analysis for MAR on 2022-05-15T16:00:00
# Executing Tweet Analysis for PWR on 2022-05-15T16:00:00
# Executing Tweet Analysis for MPRAU on 2022-05-15T16:00:00
# Executing Tweet Analysis for POAI on 2022-05-15T16:00:00
# Executing Tweet Analysis for HGEN on 2022-05-15T16:00:00
# Executing Tweet Analysis for SBNY on 2022-05-15T16:00:00
# Executing Tweet Analysis for BKCC on 2022-05-15T16:00:00
# Executing Tweet Analysis for IVCB on 2022-05-15T16:00:00
# Executing Tweet Analysis for INSW on 2022-05-15T16:00:00
# Executing Tweet Analysis for SBTX on 2022-05-15T16:00:00
# Executing Tweet Analysis for CGABL on 2022-05-15T16:00:00
# Executing Tweet Analysis for CBRGW on 2022-05-15T16:00:00
# Executing Tweet Analysis for BSM on 2022-05-15T16:00:00
# Executing Tweet Analysis for SHCRW on 2022-05-15T20:00:00
# Executing Tweet Analysis for OEPWU on 2022-05-15T20:00:00
# Executing Tweet Analysis for CREC on 2022-05-15T20:00:00
# Executing Tweet Analysis for KWR on 2022-05-15T20:00:00
# Executing Tweet Analysis for HORI on 2022-05-15T20:00:00
# Executing Tweet Analysis for ACLX on 2022-05-15T20:00:00
# Executing Tweet Analysis for IMH on 2022-05-15T20:00:00
# Executing Tweet Analysis for WNC on 2022-05-15T20:00:00
# Executing Tweet Analysis for TRIP on 2022-05-15T20:00:00
# Executing Tweet Analysis for GBX on 2022-05-15T20:00:00
# Executing Tweet Analysis for AACI on 2022-05-15T20:00:00
# Executing Tweet Analysis for COSM on 2022-05-15T20:00:00
# Executing Tweet Analysis for SQ on 2022-05-15T20:00:00
# Executing Tweet Analysis for DOCU on 2022-05-15T20:00:00
# Executing Tweet Analysis for GRC on 2022-05-15T20:00:00
# Executing Tweet Analysis for FCT on 2022-05-15T20:00:00
# Executing Tweet Analysis for WEX on 2022-05-15T20:00:00
# Executing Tweet Analysis for DRQ on 2022-05-15T20:00:00
# Executing Tweet Analysis for MAR on 2022-05-15T20:00:00
# Executing Tweet Analysis for PWR on 2022-05-15T20:00:00
# Executing Tweet Analysis for MPRAU on 2022-05-15T20:00:00
# Executing Tweet Analysis for POAI on 2022-05-15T20:00:00
# Executing Tweet Analysis for HGEN on 2022-05-15T20:00:00
# Executing Tweet Analysis for SBNY on 2022-05-15T20:00:00
# Executing Tweet Analysis for BKCC on 2022-05-15T20:00:00
# Executing Tweet Analysis for IVCB on 2022-05-15T20:00:00
# Executing Tweet Analysis for INSW on 2022-05-15T20:00:00
# Executing Tweet Analysis for SBTX on 2022-05-15T20:00:00
# Executing Tweet Analysis for CGABL on 2022-05-15T20:00:00
# Executing Tweet Analysis for CBRGW on 2022-05-15T20:00:00
# Executing Tweet Analysis for BSM on 2022-05-15T20:00:00

# %%
tweet_sentiments_all = tweet_sentiments + tweet_sentiments_2 + tweet_sentiments_3 + tweet_sentiments_4
len(tweet_sentiments_all)
# Out:
# 713

# %%
stock_tweet_sentiment_df = pd.DataFrame(tweet_sentiments_all)
#Date Clean up

#stock_tweet_sentiment_df["Date"] = stock_tweet_sentiment_df["Date"].to_timestamp()
#stock_tweet_sentiment_df["Date"] = pd.Timestamp(pd.to_datetime(stock_tweet_sentiment_df["Date"]), tz="America/New_York").isoformat()
#Check Date Type
stock_tweet_sentiment_df = stock_tweet_sentiment_df.set_index("Date")
stock_tweet_sentiment_df.index = stock_tweet_sentiment_df.index.tz_localize("UTC") 
#Sort the tweets df, reset the index after sorting and then drop the column "index"
stock_tweet_sentiment_df = stock_tweet_sentiment_df.reset_index()

# %%
stock_tweet_sentiment_df
# Out:
#                          Date Ticker  Sentiment_Score
# 0   2022-05-10 12:00:00+00:00  SHCRW         0.000000
# 1   2022-05-10 12:00:00+00:00  OEPWU         0.000000
# 2   2022-05-10 12:00:00+00:00   CREC        -0.060886
# 3   2022-05-10 12:00:00+00:00    KWR        -0.233375
# 4   2022-05-10 12:00:00+00:00   HORI         0.100716
# ..                        ...    ...              ...
# 708 2022-05-15 20:00:00+00:00   INSW         0.178263
# 709 2022-05-15 20:00:00+00:00   SBTX         0.042025
# 710 2022-05-15 20:00:00+00:00  CGABL        -0.136600
# 711 2022-05-15 20:00:00+00:00  CBRGW         0.000000
# 712 2022-05-15 20:00:00+00:00    BSM         0.067855
#
# [713 rows x 3 columns]

# %%
stock_tweet_sentiment_df = stock_tweet_sentiment_df.sort_values(by=["Ticker", "Date"])
#stock_tweet_sentiment_df = stock_tweet_sentiment_df.reset_index()
stock_tweet_sentiment_df
# Out:
#                          Date Ticker  Sentiment_Score
# 10  2022-05-10 12:00:00+00:00   AACI         0.000000
# 41  2022-05-10 16:00:00+00:00   AACI        -0.101150
# 72  2022-05-10 20:00:00+00:00   AACI        -0.067433
# 103 2022-05-11 08:00:00+00:00   AACI         0.036443
# 134 2022-05-11 12:00:00+00:00   AACI         0.036443
# ..                        ...    ...              ...
# 565 2022-05-14 20:00:00+00:00    WNC         0.203865
# 596 2022-05-15 08:00:00+00:00    WNC         0.215041
# 627 2022-05-15 12:00:00+00:00    WNC         0.256676
# 658 2022-05-15 16:00:00+00:00    WNC         0.034728
# 689 2022-05-15 20:00:00+00:00    WNC        -0.011707
#
# [713 rows x 3 columns]

# %%
stock_tweet_sentiment_df.to_csv("Data/stock_tweet_sentiment.csv")
